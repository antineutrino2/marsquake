# %%
import pandas as pd
import os
import urllib.request
import matplotlib.pyplot as plt
import requests
from io import StringIO

url = "https://service.iris.edu/irisws/mars-event/1/query?minmagnitude=1&format=text"
response = requests.get(url)
plain_text = response.text
lines = plain_text.strip().split('\n')
data = [line.split('|') for line in lines]

df = pd.DataFrame(data[1:], columns=data[0])
df['Sol'] = df['ContributorID'].str[1:4]
df
# Out:
#          EventID                       Time      Latitude    Longitude  \
# 0    mqs2022wrzi  2022-11-19T21:53:34.0000Z        4.5024     135.6234
# 1    mqs2022rbsc  2022-08-31T20:23:46.6856Z        4.5024     135.6234
# 2    mqs2022jvst  2022-05-20T23:08:41.1159Z        4.5024     135.6234
# 3    mqs2022jrva  2022-05-18T19:45:44.8461Z        4.5024     135.6234
# 4    mqs2022ivbs  2022-05-06T09:01:56.0314Z        4.5024     135.6234
# ..           ...                        ...           ...          ...
# 667  mqs2019inqk  2019-05-02T07:19:57.0000Z        4.5024     135.6234
# 668  mqs2019ilml  2019-05-01T03:03:36.0000Z        4.5024     135.6234
# 669  mqs2019hdxw  2019-04-12T18:00:20.1000Z        4.5024     135.6234
# 670  mqs2019gudd  2019-04-07T09:31:52.0000Z        4.5024     135.6234
# 671  mqs2019fddj  2019-03-14T20:59:21.0508Z  -7.734646167  165.8256263
#
#     Depth/km              Author Catalog Contributor ContributorID MagType  \
# 0             scevent@sc3mars-op                 mqs        S1415a      MW
# 1             scevent@sc3mars-op                 mqs        S1337a      MW
# 2             scevent@sc3mars-op                 mqs        S1237a      MW
# 3             scevent@sc3mars-op                 mqs        S1235a      MW
# 4             scevent@sc3mars-op                 mqs        S1223a      MW
# ..       ...                 ...     ...         ...           ...     ...
# 667           scevent@sc3mars-op                 mqs        S0152a      MW
# 668           scevent@sc3mars-op                 mqs        S0151a      MW
# 669           scevent@sc3mars-op                 mqs        S0133a      MW
# 670           scevent@sc3mars-op                 mqs        S0128a      MW
# 671           scevent@sc3mars-op                 mqs        S0105a      MW
#
#     Magnitude MagAuthor  EventLocationName            EventType  Sol
# 0         3.3            Elysium Southwest            BROADBAND  141
# 1         3.3            Elysium Southwest  VERY_HIGH_FREQUENCY  133
# 2         2.6            Elysium Southwest  VERY_HIGH_FREQUENCY  123
# 3         2.7            Elysium Southwest               2.4_HZ  123
# 4         2.9            Elysium Southwest  VERY_HIGH_FREQUENCY  122
# ..        ...       ...                ...                  ...  ...
# 667       2.9            Elysium Southwest            BROADBAND  015
# 668       1.8            Elysium Southwest               2.4_HZ  015
# 669       3.1            Elysium Southwest            BROADBAND  013
# 670       2.2            Elysium Southwest  VERY_HIGH_FREQUENCY  012
# 671       3.0             Aeolis Northeast        LOW_FREQUENCY  010
#
# [672 rows x 15 columns]
